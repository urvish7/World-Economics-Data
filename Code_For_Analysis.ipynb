# %%
# importing the libraries for the analysis

import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the csv files from the operating systems


unemployment_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/unemployment_data.csv")
corruption_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/corruption_data.csv")
cost_of_living_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/cost_of_living_data.csv")
richest_countries_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/richest_countries_data.csv")
tourism_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/tourism_data.csv")

# %% [markdown]
# Richest Countries

# %%
#displaying the table
richest_countries_df
# Out:
#            country  gdp_per_capita
# 0       Luxembourg          134754
# 1        Singapore          116486
# 2          Ireland          106456
# 3            Qatar           93521
# 4          Bermuda           85192
# 5           Norway           79201
# 6      Switzerland           77324
# 7            Macao           73802
# 8    United States           69288
# 9           Brunei           66620
# 10       Hong Kong           65973
# 11         Denmark           64651
# 12     Netherlands           63767
# 13          Sweden           59324
# 14         Belgium           58931
# 15         Austria           58427
# 16         Germany           57928
# 17         Iceland           57646
# 18       Australia           55807
# 19         Finland           55007
# 20          Canada           52085
# 21          France           50729
# 22  United Kingdom           49675
# 23    Saudi Arabia           49551
# 24           Malta           47714
# 25     South Korea           46918
# 26     New Zealand           46420
# 27           Italy           45936
# 28         Bahrain           45411
# 29         Czechia           44261
# 30          Israel           43722
# 31        Slovenia           43625
# 32           Japan           42940
# 33       Lithuania           42665
# 34         Estonia           42192
# 35           Spain           40775
# 36          Poland           37503
# 37         Hungary           36753
# 38        Portugal           35888
# 39         Romania           35414
# 40          Latvia           34469
# 41         Bahamas           34108
# 42         Croatia           33801
# 43          Russia           33361
# 44        Slovakia           33010
# 45          Panama           31680
# 46          Cyprus           31509
# 47          Greece           31295
# 48          Turkey           30472
# 49            Oman           30422

# %%
richest_countries_df.plot(x = 'country', y = 'gdp_per_capita', kind='bar', rot = 90, color = 'red',figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Unemployment data

# %%
# displaying the table
unemployment_df
# Out:
#                     country  unemployment_rate
# 0          Marshall Islands               36.0
# 1              South Africa               33.6
# 2                  Kiribati               30.6
# 3                    Kosovo               30.5
# 4            American Samoa               29.8
# ..                      ...                ...
# 59                Gibraltar                1.0
# 60                    Niger                0.8
# 61                 Cambodia                0.6
# 62                    Qatar                0.3
# 63  Cocos (Keeling) Islands                0.1
#
# [64 rows x 2 columns]

# %%
# checking on the null values
unemployment_df.isnull().sum()
# Out:
# country              0
# unemployment_rate    0
# dtype: int64

# %%
#checking the object types in the table
unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            64 non-null     object
#  1   unemployment_rate  64 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
# checking the statistics
unemployment_df.describe()
# Out:
#        unemployment_rate
# count          64.000000
# mean            7.823437
# std             8.806685
# min             0.100000
# 25%             2.700000
# 50%             5.000000
# 75%             8.250000
# max            36.000000

# %%
unemployment_df.plot(x = 'country', y = 'unemployment_rate', kind='bar', rot = 90, color = 'Magenta',figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Corruption

# %%
corruption_df
# Out:
#          country  annual_income  corruption_index
# 0        Denmark          68110                12
# 1        Finland          53660                12
# 2    New Zealand          45340                12
# 3         Norway          84090                15
# 4      Singapore          64010                15
# ..           ...            ...               ...
# 105        Yemen            670                84
# 106    Venezuela          13080                86
# 107      Somalia            450                87
# 108        Syria           1170                87
# 109  South Sudan            460                89
#
# [110 rows x 3 columns]

# %%
corruption_df.plot(x = 'country', y = 'annual_income', kind='bar', rot = 90, figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Cost of Living

# %%
# checking the null values 
cost_of_living_df.isnull().sum()
# Out:
# country                   0
# cost_index                0
# monthly_income            0
# purchasing_power_index    0
# dtype: int64

# %%
cost_of_living_df.plot(x = 'country', y = 'monthly_income', kind='bar', rot = 90,color = 'brown', figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
# The heat map

sns.heatmap(cost_of_living_df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Tourism

# %%
tourism_df
# Out:
#                  country  tourists_in_millions  receipts_in_billions  \
# 0                 France                 117.1                 35.96
# 1                 Mexico                  51.1                 11.45
# 2          United States                  45.0                 84.21
# 3                  Italy                  38.4                 20.46
# 4                Hungary                  31.6                  4.22
# 5                Croatia                  21.6                  5.63
# 6                 Turkey                  16.0                 13.77
# 7                Austria                  15.1                 15.36
# 8                Germany                  12.4                 58.37
# 9         Virgin Islands                   8.6                  0.69
# 10  United Arab Emirates                   8.1                 24.62
# 11                Greece                   7.4                  6.19
# 12           Netherlands                   7.3                 10.93
# 13                Russia                   6.4                  4.96
# 14                 Macao                   5.9                  9.44
# 15               Romania                   5.0                  1.61
# 16              Bulgaria                   5.0                  1.79
# 17              Malaysia                   4.3                  3.39
# 18              Portugal                   4.2                 10.52
# 19                 Japan                   4.1                 11.40
# 20             Indonesia                   4.1                  3.53
# 21          South Africa                   3.9                  2.72
# 22           Puerto Rico                   3.9                  2.92
# 23               Vietnam                   3.8                  3.23
# 24               Belarus                   3.6                  0.54
# 25             Hong Kong                   3.6                 32.70
# 26               Ukraine                   3.4                  0.69
# 27               Morocco                   2.8                  4.51
# 28               Albania                   2.7                  1.24
# 29               Belgium                   2.6                  7.45
# 30           South Korea                   2.5                 11.78
# 31             Australia                   1.8                 26.23
# 32           Philippines                   1.5                  2.77
# 33                Norway                   1.4                  2.20
# 34              Cambodia                   1.3                  1.12
# 35                 Qatar                   0.6                 14.32
# 36            Luxembourg                   0.5                  4.45
# 37              Ethiopia                   0.5                  2.28
# 38                Serbia                   0.4                  1.42
# 39               Bermuda                   0.1                  0.09
# 40               Moldova                   0.0                  0.35
#
#     receipts_per_tourist  percentage_of_gdp
# 0                    307                1.2
# 1                    224                0.9
# 2                   1870                0.4
# 3                    533                1.0
# 4                    133                2.3
# 5                    261                8.3
# 6                    862                1.7
# 7                   1018                3.2
# 8                   4689                1.4
# 9                     80               16.3
# 10                  3045                6.9
# 11                   836                2.9
# 12                  1504                1.1
# 13                   780                0.3
# 14                  1601               31.6
# 15                   321                0.6
# 16                   360                2.2
# 17                   781                0.9
# 18                  2500                4.2
# 19                  2769                0.2
# 20                   872                0.3
# 21                   699                0.6
# 22                   752                2.8
# 23                   842                0.9
# 24                   151                0.8
# 25                  9161                8.9
# 26                   203                0.3
# 27                  1611                3.4
# 28                   468                6.8
# 29                  2882                1.2
# 30                  4675                0.7
# 31                 14351                1.7
# 32                  1867                0.7
# 33                  1572                0.5
# 34                   857                4.2
# 35                 24601                8.0
# 36                  8484                5.1
# 37                  4405                2.1
# 38                  3188                2.3
# 39                  1829                1.3
# 40                 12207                2.6

# %%
# ploting to the bar graph
tourism_df.plot(x = 'country', y = 'tourists_in_millions', kind='bar', color = 'green',rot = 90, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
tourism_sort = tourism_df.sort_values(by='receipts_in_billions', ascending=False)

# %%
tourism_sort.plot(x = 'country', y = 'receipts_in_billions', kind='bar', rot = 90,color = 'pink', figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [raw]
# Seems like the USA has largest amount of cash flow in tourism although France has the highest visitors.
