# %%
# importing the libraries for the analysis

import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the csv files from the operating systems


unemployment_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/unemployment_data.csv")
corruption_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/corruption_data.csv")
cost_of_living_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/cost_of_living_data.csv")
richest_countries_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/richest_countries_data.csv")
tourism_df = pd.read_csv("X:/Career/Personal Projects/World-Economics-Data/archive/tourism_data.csv")

# %% [markdown]
# Richest Countries

# %%
#displaying the table
richest_countries_df
# Out:
#            country  gdp_per_capita
# 0       Luxembourg          134754
# 1        Singapore          116486
# 2          Ireland          106456
# 3            Qatar           93521
# 4          Bermuda           85192
# 5           Norway           79201
# 6      Switzerland           77324
# 7            Macao           73802
# 8    United States           69288
# 9           Brunei           66620
# 10       Hong Kong           65973
# 11         Denmark           64651
# 12     Netherlands           63767
# 13          Sweden           59324
# 14         Belgium           58931
# 15         Austria           58427
# 16         Germany           57928
# 17         Iceland           57646
# 18       Australia           55807
# 19         Finland           55007
# 20          Canada           52085
# 21          France           50729
# 22  United Kingdom           49675
# 23    Saudi Arabia           49551
# 24           Malta           47714
# 25     South Korea           46918
# ...

# %%
richest_countries_df.plot(x = 'country', y = 'gdp_per_capita', kind='bar', rot = 90, color = 'grey',figsize=(15, 20))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Unemployment data

# %%
# displaying the table
unemployment_df
# Out:
#                     country  unemployment_rate
# 0          Marshall Islands               36.0
# 1              South Africa               33.6
# 2                  Kiribati               30.6
# 3                    Kosovo               30.5
# 4            American Samoa               29.8
# ..                      ...                ...
# 59                Gibraltar                1.0
# 60                    Niger                0.8
# 61                 Cambodia                0.6
# 62                    Qatar                0.3
# 63  Cocos (Keeling) Islands                0.1
#
# [64 rows x 2 columns]

# %%
# checking on the null values
unemployment_df.isnull().sum()
# Out:
# country              0
# unemployment_rate    0
# dtype: int64

# %%
#checking the object types in the table
unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            64 non-null     object
#  1   unemployment_rate  64 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
# checking the statistics
unemployment_df.describe()
# Out:
#        unemployment_rate
# count          64.000000
# mean            7.823437
# std             8.806685
# min             0.100000
# 25%             2.700000
# 50%             5.000000
# 75%             8.250000
# max            36.000000

# %%
unemployment_df.plot(x = 'country', y = 'unemployment_rate', kind='bar', rot = 90, color = 'red',figsize=(25, 50))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Corruption

# %%
corruption_df
# Out:
#          country  annual_income  corruption_index
# 0        Denmark          68110                12
# 1        Finland          53660                12
# 2    New Zealand          45340                12
# 3         Norway          84090                15
# 4      Singapore          64010                15
# ..           ...            ...               ...
# 105        Yemen            670                84
# 106    Venezuela          13080                86
# 107      Somalia            450                87
# 108        Syria           1170                87
# 109  South Sudan            460                89
#
# [110 rows x 3 columns]

# %%
corruption_df.plot(x = 'country', y = 'annual_income', kind='bar', rot = 90, figsize=(25, 50))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# Cost of Living

# %%
# checking the null values 
cost_of_living_df.isnull().sum()
# Out:
# country                   0
# cost_index                0
# monthly_income            0
# purchasing_power_index    0
# dtype: int64

# %%
cost_of_living_df.plot(x = 'country', y = 'monthly_income', kind='bar', rot = 90,color = 'brown', figsize=(25, 50))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
# The heat map

sns.heatmap(cost_of_living_df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Tourism

# %%
tourism_df
# Out:
#                  country  tourists_in_millions  receipts_in_billions  \
# 0                 France                 117.1                 35.96
# 1                 Mexico                  51.1                 11.45
# 2          United States                  45.0                 84.21
# 3                  Italy                  38.4                 20.46
# 4                Hungary                  31.6                  4.22
# 5                Croatia                  21.6                  5.63
# 6                 Turkey                  16.0                 13.77
# 7                Austria                  15.1                 15.36
# 8                Germany                  12.4                 58.37
# 9         Virgin Islands                   8.6                  0.69
# 10  United Arab Emirates                   8.1                 24.62
# 11                Greece                   7.4                  6.19
# 12           Netherlands                   7.3                 10.93
# ...

# %%
# ploting to the bar graph
tourism_df.plot(x = 'country', y = 'tourists_in_millions', kind='bar', color = 'green',rot = 90, figsize=(25,50))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
tourism_sort = tourism_df.sort_values(by='receipts_in_billions', ascending=False)

# %%
tourism_sort.plot(x = 'country', y = 'receipts_in_billions', kind='bar', rot = 90,color = 'pink', figsize=(25, 50))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [raw]
# Seems like the USA has largest amount of cash flow in tourism although France has the highest visitors.
